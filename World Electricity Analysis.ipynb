# %%
import numpy as np
import pandas as pd

# %%
pwd()
# Out:
# 'C:\\Users\\Deepak\\world_bank_electricity_report'

# %%
df = pd.read_json('access_to_elec_rural__world/API_EG.ELC.ACCS.RU.ZS_DS2_en_csv_v2_4364070.json')

# %% [markdown]
# # Pandas Convert Row to Column Header in DataFrame

# %%
df.head()
# Out:
#                             0             1   \
# 0            Last Updated Date    2022-07-20
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
#
#                                                   2                  3   \
# 0
# 1                                     Indicator Name     Indicator Code
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#        4       5       6       7       8       9   ...                57  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 1  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013
# 2     NaN     NaN     NaN     NaN     NaN     NaN  ...               100
# ...

# %%
header_row = df.iloc[1]
header_row
# Out:
# 0       Country Name
# 1       Country Code
# 2     Indicator Name
# 3     Indicator Code
# 4             1960.0
#            ...
# 62              2018
# 63              2019
# 64              2020
# 65            2021.0
# 66
# Name: 1, Length: 67, dtype: object

# %%
df = pd.DataFrame(df.values[2:], columns=header_row)
df.head()
# Out:
# 1                 Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
# 1                                     Indicator Name     Indicator Code  \
# 0  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
# 1 1960.0 1961.0 1962.0 1963.0 1964.0 1965.0  ...              2013  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  ...               100
# 1    NaN    NaN    NaN    NaN    NaN    NaN  ...  18.6635016376268
# ...

# %%
df.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                  1960.0,           1961.0,           1962.0,           1963.0,
#                  1964.0,           1965.0,           1966.0,           1967.0,
#                  1968.0,           1969.0,           1970.0,           1971.0,
#                  1972.0,           1973.0,           1974.0,           1975.0,
#                  1976.0,           1977.0,           1978.0,           1979.0,
#                  1980.0,           1981.0,           1982.0,           1983.0,
#                  1984.0,           1985.0,           1986.0,           1987.0,
#                  1988.0,           1989.0,           '1990',           '1991',
#                  '1992',           '1993',           '1994',           '1995',
#                  '1996',           '1997',           '1998',           '1999',
#                  '2000',           '2001',           '2002',           '2003',
# ...

# %%
df.columns[0:5]
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        1960.0],
#       dtype='object', name=1)

# %%
df.columns[[0,1,2,3,4,5,6]]
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                  1960.0,           1961.0,           1962.0],
#       dtype='object', name=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960.0          0 non-null      object
#  5   1961.0          0 non-null      object
#  6   1962.0          0 non-null      object
#  7   1963.0          0 non-null      object
#  8   1964.0          0 non-null      object
#  9   1965.0          0 non-null      object
#  10  1966.0          0 non-null      object
#  11  1967.0          0 non-null      object
#  12  1968.0          0 non-null      object
#  13  1969.0          0 non-null      object
#  14  1970.0          0 non-null      object
#  15  1971.0          0 non-null      object
#  16  1972.0          0 non-null      object
# ...

# %% [markdown]
# # How to drop one or multiple columns in Pandas Dataframe

# %%
df.head()
# Out:
# 1                 Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
# 1                                     Indicator Name     Indicator Code  \
# 0  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
# 1 1960.0 1961.0 1962.0 1963.0 1964.0 1965.0  ...              2013  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  ...               100
# 1    NaN    NaN    NaN    NaN    NaN    NaN  ...  18.6635016376268
# ...

# %%
df.iloc[:, 4:33]
# Out:
# 1   1960.0 1961.0 1962.0 1963.0 1964.0 1965.0 1966.0 1967.0 1968.0 1969.0  \
# 0      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 261    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 262    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 263    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 264    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 265    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# 1    ... 1979.0 1980.0 1981.0 1982.0 1983.0 1984.0 1985.0 1986.0 1987.0 1988.0
# ...

# %%
df
# Out:
# 1                   Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# 1                                       Indicator Name     Indicator Code  \
# 0    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...

# %%
df.drop(df.iloc[:,4:33], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 38 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1989.0          0 non-null      object
#  5   1990            266 non-null    object
#  6   1991            266 non-null    object
#  7   1992            266 non-null    object
#  8   1993            266 non-null    object
#  9   1994            266 non-null    object
#  10  1995            266 non-null    object
#  11  1996            266 non-null    object
#  12  1997            266 non-null    object
#  13  1998            266 non-null    object
#  14  1999            266 non-null    object
#  15  2000            266 non-null    object
#  16  2001            266 non-null    object
# ...

# %%
df.columns[[4,36]]
# Out:
# Index([1989.0, 2021.0], dtype='object', name=1)

# %%
df.drop(df.columns[[4,36]], axis=1, inplace=True)

# %%
df.head()
# Out:
# 1                 Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
# 1                                     Indicator Name     Indicator Code 1990  \
# 0  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS  100
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
# 1              1991              1992              1993              1994  \
# 0  98.3737741616736  98.4282597493425  98.5017492013514               100
# 1
# 2
# 3                                      12.1566498971678  12.4645979175816
# 4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1990            266 non-null    object
#  5   1991            266 non-null    object
#  6   1992            266 non-null    object
#  7   1993            266 non-null    object
#  8   1994            266 non-null    object
#  9   1995            266 non-null    object
#  10  1996            266 non-null    object
#  11  1997            266 non-null    object
#  12  1998            266 non-null    object
#  13  1999            266 non-null    object
#  14  2000            266 non-null    object
#  15  2001            266 non-null    object
#  16  2002            266 non-null    object
# ...

# %%
df.iloc[:, 4:34]
# Out:
# 1   1990              1991              1992              1993  \
# 0    100  98.3737741616736  98.4282597493425  98.5017492013514
# 1
# 2
# 3                                             12.1566498971678
# 4
# ..   ...               ...               ...               ...
# 261  100               100               100               100
# 262                         30.7704468883827  25.8951904860915
# 263
# 264                         6.67226875555072
# 265                          3.0640699844598  6.81137772522481
#
# 1                 1994              1995              1996              1997  \
# 0                  100               100               100               100
# 1
# 2
# 3     12.4645979175816  12.8617673653824  12.7234761439132  15.0914758808784
# 4
# ..                 ...               ...               ...               ...
# 261                100               100               100               100
# ...

# %%
df.iloc[10:15]
# Out:
# 1          Country Name Country Code  \
# 10              Armenia          ARM
# 11       American Samoa          ASM
# 12  Antigua and Barbuda          ATG
# 13            Australia          AUS
# 14              Austria          AUT
#
# 1                                      Indicator Name     Indicator Code  \
# 10  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 11  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 12  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 13  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 14  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
# 1               1990              1991              1992              1993  \
# 10
# 11
# 12  93.4386347880213  93.7098652152215  94.0200279031483  94.3252592019729
# 13               100               100               100               100
# ...

# %%
df['1990'].sum()
# Out:
# '10010010010078.894588320131593.438634788021310010010010099.505887061827210010010010058.948432024138399.974856951616310010010010010059.45831029713371.686821238510310010010010010010010010010010010010010010010010010099.628236196043199.386693524030410010010010010010010010058.81785656018690.118866835628610087.157126006117999.848229174724510010010010010010010010010010010098.291560257515810099.81202437528644.0439137253607510010010098.49472648328910040.52385932089792.181954010003110099.765215706199410099.992029961496810010010010010019.454813216517810010010010010010056.641897560416710010094.0837968319117100100'

# %%
df.iloc[39]
# Out:
# 1
# Country Name                                                  Chile
# Country Code                                                    CHL
# Indicator Name    Access to electricity, rural (% of rural popul...
# Indicator Code                                    EG.ELC.ACCS.RU.ZS
# 1990                                                59.458310297133
# 1991                                               72.6529187893954
# 1992                                               71.4397443359869
# 1993                                               74.0618441426621
# 1994                                               74.7053747121922
# 1995                                               75.4195550331526
# 1996                                               74.1794729751692
# 1997                                               77.1353797964394
# 1998                                               82.9624556298822
# 1999                                               79.3576862813837
# ...

# %%
for i in range(267):
    print(df.iloc[i])
# Out:
# 1
# Country Name                                                  Aruba
# Country Code                                                    ABW
# Indicator Name    Access to electricity, rural (% of rural popul...
# Indicator Code                                    EG.ELC.ACCS.RU.ZS
# 1990                                                            100
# 1991                                               98.3737741616736
# 1992                                               98.4282597493425
# 1993                                               98.5017492013514
# 1994                                                            100
# 1995                                                            100
# 1996                                                            100
# 1997                                                            100
# 1998                                                            100
# 1999                                                            100
# ...

# %%
df.describe()
# Out:
# 1      Country Name Country Code  \
# count           266          266
# unique          266          266
# top           Aruba          ABW
# freq              1            1
#
# 1                                          Indicator Name     Indicator Code  \
# count                                                 266                266
# unique                                                  1                  1
# top     Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# freq                                                  266                266
#
# 1      1990 1991 1992 1993 1994 1995  ... 2012 2013 2014 2015 2016 2017 2018  \
# count   266  266  266  266  266  266  ...  266  266  266  266  266  266  266
# unique   26   38   53   63   69   73  ...  159  161  154  155  150  142  142
# top                                   ...  100  100  100  100  100  100  100
# freq    166  155  140  126  119  111  ...   94   94  103  104  104  109  107
#
# 1      2019 2020
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1990            266 non-null    object
#  5   1991            266 non-null    object
#  6   1992            266 non-null    object
#  7   1993            266 non-null    object
#  8   1994            266 non-null    object
#  9   1995            266 non-null    object
#  10  1996            266 non-null    object
#  11  1997            266 non-null    object
#  12  1998            266 non-null    object
#  13  1999            266 non-null    object
#  14  2000            266 non-null    object
#  15  2001            266 non-null    object
#  16  2002            266 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', ''],
#       dtype='object', name=1)

# %%
df.drop(df[df.columns[35]], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1990            266 non-null    object
#  5   1991            266 non-null    object
#  6   1992            266 non-null    object
#  7   1993            266 non-null    object
#  8   1994            266 non-null    object
#  9   1995            266 non-null    object
#  10  1996            266 non-null    object
#  11  1997            266 non-null    object
#  12  1998            266 non-null    object
#  13  1999            266 non-null    object
#  14  2000            266 non-null    object
#  15  2001            266 non-null    object
#  16  2002            266 non-null    object
# ...

# %%
df[df.columns[4:35]] = df[df.columns[4:35]].apply(pd.to_numeric)

# %%
df[df.columns[4:35]]
# Out:
# 1     1990        1991        1992        1993        1994        1995  \
# 0    100.0   98.373774   98.428260   98.501749  100.000000  100.000000
# 1      NaN         NaN         NaN         NaN         NaN         NaN
# 2      NaN         NaN         NaN         NaN         NaN         NaN
# 3      NaN         NaN         NaN   12.156650   12.464598   12.861767
# 4      NaN         NaN         NaN         NaN         NaN         NaN
# ..     ...         ...         ...         ...         ...         ...
# 261  100.0  100.000000  100.000000  100.000000  100.000000  100.000000
# 262    NaN         NaN   30.770447   25.895190   26.937879   28.040667
# 263    NaN         NaN         NaN         NaN         NaN         NaN
# 264    NaN         NaN    6.672269         NaN    0.572325    1.291556
# 265    NaN         NaN    3.064070    6.811378    4.233107    7.021267
#
# 1          1996        1997        1998        1999  ...        2011  \
# ...

# %%
df.isna().sum()
# Out:
# 1
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1990              166
# 1991              155
# 1992              140
# 1993              126
# 1994              119
# 1995              111
# 1996              101
# 1997               99
# 1998               93
# 1999               87
# 2000               28
# 2001               28
# 2002               28
# 2003               19
# 2004               15
# 2005               17
# 2006               15
# 2007               15
# 2008               14
# 2009               16
# 2010               14
# 2011               13
# 2012               13
# 2013               11
# 2014                9
# 2015                7
# 2016               11
# 2017               15
# 2018               16
# 2019               15
# 2020                9
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1990            100 non-null    float64
#  5   1991            111 non-null    float64
#  6   1992            126 non-null    float64
#  7   1993            140 non-null    float64
#  8   1994            147 non-null    float64
#  9   1995            155 non-null    float64
#  10  1996            165 non-null    float64
#  11  1997            167 non-null    float64
#  12  1998            173 non-null    float64
#  13  1999            179 non-null    float64
#  14  2000            238 non-null    float64
#  15  2001            238 non-null    float64
#  16  2002            238 non-null    float64
# ...

# %%
df.drop(df.iloc[:, 4:14], axis=1, inplace=True)

# %%
df1 = df
df1
# Out:
# 1                   Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# 1                                       Indicator Name     Indicator Code  \
# 0    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...

# %%
df['2000'].sum()  #nan rahne ke baad bhi sahi answer hi aata hai
# Out:
# 16894.354581799882

# %%
df['2000'][265]
# Out:
# 7.27254104614258

# %%
sum = 0
for i in range(266):
    sum = sum + df['2000'][i]
sum
# Out:
# nan

# %%
df1.isna().sum()
# Out:
# 1
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 2000              28
# 2001              28
# 2002              28
# 2003              19
# 2004              15
# 2005              17
# 2006              15
# 2007              15
# 2008              14
# 2009              16
# 2010              14
# 2011              13
# 2012              13
# 2013              11
# 2014               9
# 2015               7
# 2016              11
# 2017              15
# 2018              16
# 2019              15
# 2020               9
# dtype: int64

# %%
df1 = df1.fillna(0)

# %%
df1.isna().sum()
# Out:
# 1
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# dtype: int64

# %%
df1['2000'].summ()
# Out:
# 16894.354581799882

# %%
new_df = pd.DataFrame(df1)
new_df.tail()
# Out:
# 1    Country Name Country Code  \
# 261        Kosovo          XKX
# 262   Yemen, Rep.          YEM
# 263  South Africa          ZAF
# 264        Zambia          ZMB
# 265      Zimbabwe          ZWE
#
# 1                                       Indicator Name     Indicator Code  \
# 261  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 262  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 263  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 264  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 265  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
# 1         2000       2001       2002       2003       2004       2005  ...  \
# 261   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000  ...
# 262  33.932995  35.098572  36.264832  37.434292  32.938976  40.187141  ...
# 263  54.603973  49.242352  64.090965  66.282089  73.444923  72.833435  ...
# ...

# %%
new_df.to_csv('access_to_elec_rural__world/access_to_elec_rural__world.csv')

# %% [markdown]
# # access_to_electricity__total

# %%
df = pd.read_json('access_to_electricity__total/API_EG.ELC.ACCS.ZS_DS2_en_csv_v2_4353549.json')

# %%
df.head()
# Out:
#                             0             1   \
# 0            Last Updated Date    2022-07-20
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
#
#                                         2               3       4       5   \
# 0                                                              NaN     NaN
# 1                           Indicator Name  Indicator Code  1960.0  1961.0
# 2  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
# 3  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
# 4  Access to electricity (% of population)  EG.ELC.ACCS.ZS     NaN     NaN
#
#        6       7       8       9   ...                57               58  \
# 0     NaN     NaN     NaN     NaN  ...
# 1  1962.0  1963.0  1964.0  1965.0  ...              2013             2014
# ...

# %%
row_header = df.iloc[1]
df = pd.DataFrame(df.values[2:], columns=row_header)
df
# Out:
# 1                   Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# 1                             Indicator Name  Indicator Code 1960.0 1961.0  \
# 0    Access to electricity (% of population)  EG.ELC.ACCS.ZS    NaN    NaN
# 1    Access to electricity (% of population)  EG.ELC.ACCS.ZS    NaN    NaN
# 2    Access to electricity (% of population)  EG.ELC.ACCS.ZS    NaN    NaN
# 3    Access to electricity (% of population)  EG.ELC.ACCS.ZS    NaN    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960.0          0 non-null      object
#  5   1961.0          0 non-null      object
#  6   1962.0          0 non-null      object
#  7   1963.0          0 non-null      object
#  8   1964.0          0 non-null      object
#  9   1965.0          0 non-null      object
#  10  1966.0          0 non-null      object
#  11  1967.0          0 non-null      object
#  12  1968.0          0 non-null      object
#  13  1969.0          0 non-null      object
#  14  1970.0          0 non-null      object
#  15  1971.0          0 non-null      object
#  16  1972.0          0 non-null      object
# ...

# %%
df.drop(df.iloc[:,4:44], axis=1, inplace=True)

# %%
df
# Out:
# 1                   Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# 1                             Indicator Name  Indicator Code  \
# 0    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 1    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 2    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 3    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 4    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   2000            266 non-null    object
#  5   2001            266 non-null    object
#  6   2002            266 non-null    object
#  7   2003            266 non-null    object
#  8   2004            266 non-null    object
#  9   2005            266 non-null    object
#  10  2006            266 non-null    object
#  11  2007            266 non-null    object
#  12  2008            266 non-null    object
#  13  2009            266 non-null    object
#  14  2010            266 non-null    object
#  15  2011            266 non-null    object
#  16  2012            266 non-null    object
# ...

# %%
df.drop(df.columns[25:], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   2000            266 non-null    object
#  5   2001            266 non-null    object
#  6   2002            266 non-null    object
#  7   2003            266 non-null    object
#  8   2004            266 non-null    object
#  9   2005            266 non-null    object
#  10  2006            266 non-null    object
#  11  2007            266 non-null    object
#  12  2008            266 non-null    object
#  13  2009            266 non-null    object
#  14  2010            266 non-null    object
#  15  2011            266 non-null    object
#  16  2012            266 non-null    object
# ...

# %%
df[df.columns[4:]] = df[df.columns[4:]].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   2000            259 non-null    float64
#  5   2001            259 non-null    float64
#  6   2002            260 non-null    float64
#  7   2003            260 non-null    float64
#  8   2004            260 non-null    float64
#  9   2005            260 non-null    float64
#  10  2006            261 non-null    float64
#  11  2007            262 non-null    float64
#  12  2008            262 non-null    float64
#  13  2009            263 non-null    float64
#  14  2010            264 non-null    float64
#  15  2011            263 non-null    float64
#  16  2012            264 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# 1
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 2000              7
# 2001              7
# 2002              6
# 2003              6
# 2004              6
# 2005              6
# 2006              5
# 2007              4
# 2008              4
# 2009              3
# 2010              2
# 2011              3
# 2012              2
# 2013              2
# 2014              2
# 2015              2
# 2016              2
# 2017              2
# 2018              3
# 2019              2
# 2020              3
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isna().sum()
# Out:
# 1
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# dtype: int64

# %%
df.describe()
# Out:
# 1            2000        2001        2002        2003        2004        2005  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    72.622520   73.075200   73.700624   74.338384   74.842798   75.248278
# std     34.498161   34.252334   33.759493   33.198318   32.750836   32.550761
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     43.266095   45.500031   46.893553   49.117058   51.122625   55.020044
# 50%     92.369947   93.374325   93.753084   93.588160   93.880109   94.364833
# 75%    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
# 1            2006        2007        2008        2009  ...        2011  \
# count  266.000000  266.000000  266.000000  266.000000  ...  266.000000
# mean    76.155889   76.605060   77.181653   77.644646  ...   79.029607
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020'],
#       dtype='object', name=1)

# %%
df['2000']
# Out:
# 0      91.660400
# 1      19.811283
# 2       1.613591
# 3      34.150687
# 4      24.212744
#          ...
# 261     0.000000
# 262    49.187256
# 263    72.282463
# 264    16.700001
# 265    33.654888
# Name: 2000, Length: 266, dtype: float64

# %%
for i in df['2000']:
    print(i)
# Out:
# 91.660400390625
# 19.8112830487474
# 1.61359095573425
# 34.1506868375937
# 24.2127437591553
# 100.0
# 100.0
# 80.7361412102573
# 100.0
# 95.7832870483398
# 98.9000015258789
# 0.0
# 97.6892623901367
# 100.0
# 100.0
# 98.9082260131836
# 2.46323680877686
# 100.0
# 21.5310840606689
# 9.07501983642578
# 32.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 79.0
# 100.0
# 69.9630432128906
# 94.391716003418
# 100.0
# 100.0
# 31.1499996185303
# 26.4089794158936
# 6.0
# 100.0
# 100.0
# 100.0
# 100.0
# 97.9386901855469
# 97.0217971801758
# 48.6894683837891
# 41.0
# 6.69999980926514
# 29.090015411377
# 95.1999969482422
# 39.7153549194336
# 58.4223289489746
# 96.9400024414063
# 86.8292942974403
# 97.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 56.3799514770508
# 80.9518127441406
# 100.0
# 88.7649307250977
# 98.9730987548828
# 91.3174717523684
# 66.7030724363987
# 92.2236372239929
# 99.8816190704524
# 99.9493964240866
# 93.7322616577148
# 97.6999969482422
# 100.0
# 29.2545108795166
# 100.0
# 100.0
# ...

# %%
df.to_csv('access_to_electricity__total/access_to_electricity__total.csv')

# %%
df.to_csv('access_to_electricity__total/access_to_electricity_total.csv', index=False)
